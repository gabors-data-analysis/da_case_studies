# %% [markdown]
# ## Prepared for the textbook:
# -------------------------------------------------------------------
# ## Data Analysis for Business, Economics, and Policy
# #### by Gabor BEKES and  Gabor KEZDI
# ----------------------------------
# #### Cambridge University Press 2021
# -----------------------------------------------------------------------------------------------
# #### License: Free to share, modify and use for educational purposes. Not to be used for business purposes.

# %%
import pandas as pd
import os
from pathlib import Path
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from plotnine import *
import sys
from patsy import dmatrices

# %%
path = Path(os.getcwd())

# %%
base_dir = path.parent.parent

# %%
data_in = os.path.join(str(base_dir) , "da_data_repo/airbnb/clean/")
data_out = os.path.join(str(base_dir), "da_case_studies/ch16-airbnb-random-forest/")
output = os.path.join(str(base_dir), "da_case_studies/ch16-airbnb-random-forest/output/")
func = os.path.join(str(base_dir) ,   "da_case_studies/ch00-tech-prep/")

# %%
sys.path.append(func)
from py_helper_functions import *

# %%
#########################################################################################
#
# PART I
# Loading and preparing data ----------------------------------------------
#
#########################################################################################

# %%
area="london"
data=pd.read_csv(data_in+"airbnb_"+area+"_workfile.csv")

# %%
#####################
### look at price ###
#####################
data.price.describe()
data=data.assign(ln_price=np.log(data.price))
data=data.query("price<=1000")

# %%
# Squares and further values to create
data=data.assign(
    n_accommodates2=lambda x: x['n_accommodates']**2,
    ln_accommodates=lambda x: np.log(x['n_accommodates']),
    ln_accommodates2=lambda x: np.log(x['n_accommodates'])**2,
    ln_beds=lambda x: np.log(x['n_beds']),
    ln_number_of_reviews=lambda x: np.log(x['n_number_of_reviews']+1)
)
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log

# %%
bins = pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 10)],closed='left')
f_bath=pd.cut(data['n_bathrooms'].to_list(), bins,labels=['0','1','2'])
f_bath.categories=[0,1,2]

# %%
f_bath.value_counts(dropna=False)
# Out:
# 0        364
# 1      41417
# 2       9628
# NaN      237
# dtype: int64

# %%
# Pool accomodations with 0,1,2,10 bathrooms
data['f_bathroom']=f_bath

# %%
bins = pd.IntervalIndex.from_tuples([(0, 1), (1, 51), (51, max(data.n_number_of_reviews))],closed='left')
fnor=pd.cut(data['n_number_of_reviews'].to_list(), bins,labels=['0','1','2'])
fnor.categories=[0,1,2]
data['f_number_of_reviews']=fnor

# %%
bins = pd.IntervalIndex.from_tuples([(1, 2), (2, 3), (3, max(data.n_minimum_nights))],closed='left')
fnor=pd.cut(data['n_minimum_nights'].to_list(), bins,labels=['1','2','3'])
fnor.categories=[1,2,3]
data['f_minimum_nights']=fnor

# %%
# Change Infinite values with NaNs
data=data.replace([np.inf, -np.inf], np.nan)

# %%
data.head()
# Out:
#    usd_cleaning_fee f_property_type   f_room_type f_cancellation_policy  \
# 0               NaN       Apartment  Private room              flexible
# 1               NaN       Apartment  Private room              moderate
# 2               NaN       Apartment  Private room              flexible
# 3               NaN           House  Private room              flexible
# 4               NaN           House  Private room              flexible
#
#   f_bed_type f_neighbourhood_cleansed  usd_price_day  p_host_response_rate  \
# 0   Real Bed     Kingston upon Thames           23.0                 100.0
# 1      Couch     Kingston upon Thames           50.0                 100.0
# 2   Real Bed     Kingston upon Thames           24.0                   NaN
# 3   Real Bed     Kingston upon Thames           50.0                   NaN
# 4   Real Bed     Kingston upon Thames           25.0                 100.0
#
#    n_accommodates  n_bathrooms  ...  property_type  ln_price  n_accommodates2  \
# 0               1          1.0  ...      Apartment  3.135494                1
# 1               2          1.0  ...      Apartment  3.912023                4
# 2               2          1.0  ...      Apartment  3.178054                4
# 3               2          1.5  ...          House  3.912023                4
# 4               1          1.0  ...          House  3.218876                1
#
#    ln_accommodates  ln_accommodates2  ln_beds  ln_number_of_reviews  \
# 0         0.000000          0.000000      0.0              0.693147
# 1         0.693147          0.480453      0.0              2.772589
# 2         0.693147          0.480453      0.0              1.098612
# 3         0.693147          0.480453      0.0              0.000000
# 4         0.000000          0.000000      0.0              0.000000
#
#    f_bathroom  f_number_of_reviews  f_minimum_nights
# 0           1                    1                 3
# 1           1                    1                 1
# 2           1                    1                 1
# 3           1                    0                 2
# 4           1                    0                 1
#
# [5 rows x 82 columns]

# %%
#------------------------------------------------------------------------------------------------
# where do we have missing variables now?
to_filter=data.isna().sum()
to_filter[to_filter>0]
# Out:
# usd_cleaning_fee          20017
# p_host_response_rate      12868
# n_bathrooms                 237
# n_review_scores_rating    16501
# n_reviews_per_month       15741
# n_beds                      167
# n_days_since              15741
# ln_beds                     168
# f_bathroom                  237
# f_number_of_reviews           1
# f_minimum_nights              1
# dtype: int64

# %%
# what to do with missing values? 
# 1. drop if no target
data = data.query('price.notna()',engine='python')

# %%
# 2. imput when few, not that important
data = data.assign(
    n_bathrooms = data['n_bathrooms'].fillna(np.median(data['n_bathrooms'].dropna())),
    n_beds = [x[0] if pd.isnull(x[1]) else x[1] for x in zip(data.n_accommodates,data.n_beds)],
    f_bathroom =  data['f_bathroom'].fillna(1),
    f_minimum_nights =  data['f_minimum_nights'].fillna(1),
    f_number_of_reviews = data['f_number_of_reviews'].fillna(1),
    ln_beds =  data['ln_beds'].fillna(0)
  )

# %%
data.head()
# Out:
#    usd_cleaning_fee f_property_type   f_room_type f_cancellation_policy  \
# 0               NaN       Apartment  Private room              flexible
# 1               NaN       Apartment  Private room              moderate
# 2               NaN       Apartment  Private room              flexible
# 3               NaN           House  Private room              flexible
# 4               NaN           House  Private room              flexible
#
#   f_bed_type f_neighbourhood_cleansed  usd_price_day  p_host_response_rate  \
# 0   Real Bed     Kingston upon Thames           23.0                 100.0
# 1      Couch     Kingston upon Thames           50.0                 100.0
# 2   Real Bed     Kingston upon Thames           24.0                   NaN
# 3   Real Bed     Kingston upon Thames           50.0                   NaN
# 4   Real Bed     Kingston upon Thames           25.0                 100.0
#
#    n_accommodates  n_bathrooms  ...  property_type  ln_price  n_accommodates2  \
# 0               1          1.0  ...      Apartment  3.135494                1
# 1               2          1.0  ...      Apartment  3.912023                4
# 2               2          1.0  ...      Apartment  3.178054                4
# 3               2          1.5  ...          House  3.912023                4
# 4               1          1.0  ...          House  3.218876                1
#
#    ln_accommodates  ln_accommodates2  ln_beds  ln_number_of_reviews  \
# 0         0.000000          0.000000      0.0              0.693147
# 1         0.693147          0.480453      0.0              2.772589
# 2         0.693147          0.480453      0.0              1.098612
# 3         0.693147          0.480453      0.0              0.000000
# 4         0.000000          0.000000      0.0              0.000000
#
#    f_bathroom  f_number_of_reviews  f_minimum_nights
# 0           1                    1                 3
# 1           1                    1                 1
# 2           1                    1                 1
# 3           1                    0                 2
# 4           1                    0                 1
#
# [5 rows x 82 columns]

# %%
data=data.drop(["usd_cleaning_fee", "p_host_response_rate"],axis=1)

# %%
to_filter=data.isna().sum()
to_filter[to_filter>0]
# Out:
# n_review_scores_rating    16501
# n_reviews_per_month       15741
# n_days_since              15741
# dtype: int64

# %%
data
# Out:
#       f_property_type      f_room_type f_cancellation_policy f_bed_type  \
# 0           Apartment     Private room              flexible   Real Bed
# 1           Apartment     Private room              moderate      Couch
# 2           Apartment     Private room              flexible   Real Bed
# 3               House     Private room              flexible   Real Bed
# 4               House     Private room              flexible   Real Bed
# ...               ...              ...                   ...        ...
# 51692       Apartment     Private room                strict   Real Bed
# 51693           House  Entire home/apt              flexible   Real Bed
# 51694       Apartment  Entire home/apt              flexible   Real Bed
# 51695       Apartment  Entire home/apt              flexible   Real Bed
# 51696       Apartment     Private room              flexible   Real Bed
#
#       f_neighbourhood_cleansed  usd_price_day  n_accommodates  n_bathrooms  \
# 0         Kingston upon Thames           23.0               1          1.0
# 1         Kingston upon Thames           50.0               2          1.0
# 2         Kingston upon Thames           24.0               2          1.0
# 3         Kingston upon Thames           50.0               2          1.5
# 4         Kingston upon Thames           25.0               1          1.0
# ...                        ...            ...             ...          ...
# 51692              Westminster           24.0               1          1.0
# 51693     Richmond upon Thames          120.0               6          1.0
# 51694               Wandsworth          215.0               6          3.0
# 51695                 Hounslow          150.0               4          2.0
# 51696            Tower Hamlets           90.0               2          1.0
#
#        n_review_scores_rating  n_number_of_reviews  ...  property_type  \
# 0                       100.0                    1  ...      Apartment
# 1                        91.0                   15  ...      Apartment
# 2                        80.0                    2  ...      Apartment
# 3                         NaN                    0  ...          House
# 4                         NaN                    0  ...          House
# ...                       ...                  ...  ...            ...
# 51692                    40.0                    1  ...      Apartment
# 51693                     NaN                    0  ...          House
# 51694                     NaN                    0  ...      Apartment
# 51695                     NaN                    0  ...      Apartment
# 51696                     NaN                    0  ...      Apartment
#
#        ln_price  n_accommodates2  ln_accommodates  ln_accommodates2   ln_beds  \
# 0      3.135494                1         0.000000          0.000000  0.000000
# 1      3.912023                4         0.693147          0.480453  0.000000
# 2      3.178054                4         0.693147          0.480453  0.000000
# 3      3.912023                4         0.693147          0.480453  0.000000
# 4      3.218876                1         0.000000          0.000000  0.000000
# ...         ...              ...              ...               ...       ...
# 51692  3.178054                1         0.000000          0.000000  0.000000
# 51693  4.787492               36         1.791759          3.210402  1.791759
# 51694  5.370638               36         1.791759          3.210402  1.609438
# 51695  5.010635               16         1.386294          1.921812  0.693147
# 51696  4.499810                4         0.693147          0.480453  0.000000
#
#        ln_number_of_reviews  f_bathroom  f_number_of_reviews  f_minimum_nights
# 0                  0.693147           1                    1                 3
# 1                  2.772589           1                    1                 1
# 2                  1.098612           1                    1                 1
# 3                  0.000000           1                    0                 2
# 4                  0.000000           1                    0                 1
# ...                     ...         ...                  ...               ...
# 51692              0.693147           1                    1                 3
# 51693              0.000000           1                    0                 3
# 51694              0.000000           2                    0                 3
# 51695              0.000000           2                    0                 3
# 51696              0.000000           1                    0                 1
#
# [51646 rows x 80 columns]

# %%
# 4. Replace missing variables re reviews with zero, when no review + add flags
data=data.assign(
    flag_days_since=np.multiply(data.n_days_since.isna(),1),
    n_days_since=data.n_days_since.fillna(np.median(data.n_days_since.dropna())),
    flag_review_scores_rating=np.multiply(data.n_review_scores_rating.isna(),1),
    n_review_scores_rating=data.n_review_scores_rating.fillna(np.median(data.n_review_scores_rating.dropna())),
    flag_reviews_per_month=np.multiply(data.n_reviews_per_month.isna(),1),
    n_reviews_per_month=data.n_reviews_per_month.fillna(np.median(data.n_reviews_per_month.dropna())),
    flag_n_number_of_reviews=np.multiply(data.n_number_of_reviews.isna(),1)
)

# %%
data.flag_days_since.value_counts()
# Out:
# 0    35905
# 1    15741
# Name: flag_days_since, dtype: int64

# %%
# redo features
# Create variables, measuring the time since: squared, cubic, logs
data=data.assign(
    ln_days_since =lambda x: np.log(x['n_days_since']+1),
    ln_days_since2 =lambda x:  np.log(x['n_days_since']+1)**2,
    ln_days_since3 =lambda x:  np.log(x['n_days_since']+1)**3 ,
    n_days_since2=data.n_days_since**2,
    n_days_since3=data.n_days_since**3,
    ln_review_scores_rating=np.log(data.n_review_scores_rating)
)

# %%
data.ln_days_since=data.ln_days_since.fillna(0)
data.ln_days_since2=data.ln_days_since2.fillna(0)
data.ln_days_since3=data.ln_days_since3.fillna(0)

# %%
to_filter=data.isna().sum()
to_filter[to_filter>0]
# Out:
# Series([], dtype: int64)

# %%
data.to_csv(data_out+"airbnb_london_workfile_adj.csv",index=False)
